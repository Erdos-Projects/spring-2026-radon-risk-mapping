# %%
from pathlib import Path
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import os

from sklearn.metrics import (
    roc_auc_score,
    average_precision_score,
    log_loss,
    brier_score_loss,
    f1_score,
    recall_score,
    accuracy_score,
    precision_recall_curve,
    roc_curve,
)

# define project root
PROJECT_ROOT = Path.cwd().parent.parent
sys.path.append(str(PROJECT_ROOT))

from config.paths import RESULTS_DIR, FIGURES_DIR, MODEL_RUNS_DIR

# %%
def expected_calibration_error(y_true, y_prob, n_bins=10):
    y_true = np.asarray(y_true)
    y_prob = np.asarray(y_prob)

    bins = np.linspace(0.0, 1.0, n_bins + 1)
    bin_ids = np.digitize(y_prob, bins) - 1
    bin_ids = np.clip(bin_ids, 0, n_bins - 1)

    ece = 0.0
    for bin_idx in range(n_bins):
        mask = bin_ids == bin_idx
        if np.any(mask):
            mean_prob = y_prob[mask].mean()
            mean_true = y_true[mask].mean()
            ece += mask.mean() * abs(mean_prob - mean_true)
    return ece

# %%
print("PROJECT_ROOT:", PROJECT_ROOT)
print("FIGURES_DIR:", FIGURES_DIR)
print("RESULTS_DIR:", RESULTS_DIR)
print("MODEL_RUNS_DIR:", MODEL_RUNS_DIR)

logreg_run_dir = MODEL_RUNS_DIR / "logreg_overnight_2026_03_20_neg_log_loss_20260320_021633"
xgboost_run_dir = MODEL_RUNS_DIR / "xgboost_overnight_2026_03_20_neg_log_loss_20260320_035024"
random_forest_run_dir = MODEL_RUNS_DIR / "random_forest_overnight_2026_03_20_neg_log_loss_20260320_031327"

selected_run_dirs = [
    logreg_run_dir,
    random_forest_run_dir,
    xgboost_run_dir,
]

summary_files = [run_dir / "summary_metrics.csv" for run_dir in selected_run_dirs]
fold_files = [run_dir / "outer_fold_results.csv" for run_dir in selected_run_dirs]
oof_files = [run_dir / "oof_predictions.csv" for run_dir in selected_run_dirs]

print("summary_files:")
for f in summary_files:
    print("  ", f, "| exists:", f.exists())

print("\nfold_files:")
for f in fold_files:
    print("  ", f, "| exists:", f.exists())

print("\noof_files:")
for f in oof_files:
    print("  ", f, "| exists:", f.exists())
# Out:
# PROJECT_ROOT: c:\Users\john\Desktop\spring-2026-radon-risk-mapping
# FIGURES_DIR: C:\Users\john\Desktop\spring-2026-radon-risk-mapping\figures
# RESULTS_DIR: C:\Users\john\Desktop\spring-2026-radon-risk-mapping\results
# MODEL_RUNS_DIR: C:\Users\john\Desktop\spring-2026-radon-risk-mapping\results\model_runs
# summary_files:
#    C:\Users\john\Desktop\spring-2026-radon-risk-mapping\results\model_runs\logreg_overnight_2026_03_20_neg_log_loss_20260320_021633\summary_metrics.csv | exists: True
#    C:\Users\john\Desktop\spring-2026-radon-risk-mapping\results\model_runs\random_forest_overnight_2026_03_20_neg_log_loss_20260320_031327\summary_metrics.csv | exists: True
#    C:\Users\john\Desktop\spring-2026-radon-risk-mapping\results\model_runs\xgboost_overnight_2026_03_20_neg_log_loss_20260320_035024\summary_metrics.csv | exists: True
#
# fold_files:
#    C:\Users\john\Desktop\spring-2026-radon-risk-mapping\results\model_runs\logreg_overnight_2026_03_20_neg_log_loss_20260320_021633\outer_fold_results.csv | exists: True
#    C:\Users\john\Desktop\spring-2026-radon-risk-mapping\results\model_runs\random_forest_overnight_2026_03_20_neg_log_loss_20260320_031327\outer_fold_results.csv | exists: True
#    C:\Users\john\Desktop\spring-2026-radon-risk-mapping\results\model_runs\xgboost_overnight_2026_03_20_neg_log_loss_20260320_035024\outer_fold_results.csv | exists: True
#
# oof_files:
#    C:\Users\john\Desktop\spring-2026-radon-risk-mapping\results\model_runs\logreg_overnight_2026_03_20_neg_log_loss_20260320_021633\oof_predictions.csv | exists: True
#    C:\Users\john\Desktop\spring-2026-radon-risk-mapping\results\model_runs\random_forest_overnight_2026_03_20_neg_log_loss_20260320_031327\oof_predictions.csv | exists: True
#    C:\Users\john\Desktop\spring-2026-radon-risk-mapping\results\model_runs\xgboost_overnight_2026_03_20_neg_log_loss_20260320_035024\oof_predictions.csv | exists: True

# %%
summary_dfs = []

for file in summary_files:
    df = pd.read_csv(file)
    df["run_dir"] = str(file.parent)
    summary_dfs.append(df)

all_summaries = pd.concat(summary_dfs, ignore_index=True)

print(all_summaries.columns.tolist())
all_summaries
# Out:
# ['model_name', 'run_id', 'batch_tag', 'search_scoring', 'n_rows', 'positive_rate', 'n_outer_folds', 'oof_roc_auc', 'oof_aucpr', 'oof_log_loss', 'oof_brier', 'oof_ece', 'oof_f1', 'oof_recall', 'mean_fold_roc_auc', 'mean_fold_aucpr', 'mean_fold_log_loss', 'mean_fold_brier', 'mean_fold_ece', 'run_dir', 'classification_threshold', 'n_calibration_bins', 'oof_accuracy']
#       model_name                                             run_id  \
# 0         logreg  logreg_overnight_2026_03_20_neg_log_loss_20260...
# 1  random_forest  random_forest_overnight_2026_03_20_neg_log_los...
# 2        xgboost  xgboost_overnight_2026_03_20_neg_log_loss_2026...
#
#               batch_tag search_scoring  n_rows  positive_rate  n_outer_folds  \
# 0  overnight_2026_03_20   neg_log_loss   10461       0.108594              5
# 1  overnight_2026_03_20   neg_log_loss   10461       0.108594              5
# 2  overnight_2026_03_20   neg_log_loss   10461       0.108594              5
#
#    oof_roc_auc  oof_aucpr  oof_log_loss  ...  oof_recall  mean_fold_roc_auc  \
# 0     0.628664   0.171108      0.333744  ...    0.705106           0.635632
# 1     0.649478   0.183600      0.329423  ...    0.669014           0.651206
# 2     0.648099   0.181639      0.329914  ...    0.661972           0.657799
#
#    mean_fold_aucpr  mean_fold_log_loss  mean_fold_brier  mean_fold_ece  \
# 0         0.179859            0.333775         0.094777       0.026603
# 1         0.189849            0.329490         0.093928       0.020740
# 2         0.187037            0.329943         0.094074       0.024052
#
#                                              run_dir  \
# 0  C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 1  C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 2  C:\Users\john\Desktop\spring-2026-radon-risk-m...
#
#    classification_threshold  n_calibration_bins oof_accuracy
# 0                       NaN                 NaN          NaN
# 1                       0.1                10.0     0.559889
# 2                       0.1                10.0     0.540101
#
# [3 rows x 23 columns]

# %%
fold_dfs = []

for file in fold_files:
    df = pd.read_csv(file)
    df["run_dir"] = str(file.parent)
    fold_dfs.append(df)

all_folds_df = pd.concat(fold_dfs, ignore_index=True)

print(all_folds_df.columns.tolist())
all_folds_df
# Out:
# ['model_name', 'run_id', 'outer_fold', 'n_train', 'n_val', 'train_positive_rate', 'val_positive_rate', 'roc_auc', 'aucpr', 'log_loss', 'brier', 'ece', 'f1', 'recall', 'accuracy', 'best_params_json', 'run_dir']
#        model_name                                             run_id  \
# 0          logreg  logreg_overnight_2026_03_20_neg_log_loss_20260...
# 1          logreg  logreg_overnight_2026_03_20_neg_log_loss_20260...
# 2          logreg  logreg_overnight_2026_03_20_neg_log_loss_20260...
# 3          logreg  logreg_overnight_2026_03_20_neg_log_loss_20260...
# 4          logreg  logreg_overnight_2026_03_20_neg_log_loss_20260...
# 5   random_forest  random_forest_overnight_2026_03_20_neg_log_los...
# 6   random_forest  random_forest_overnight_2026_03_20_neg_log_los...
# 7   random_forest  random_forest_overnight_2026_03_20_neg_log_los...
# 8   random_forest  random_forest_overnight_2026_03_20_neg_log_los...
# 9   random_forest  random_forest_overnight_2026_03_20_neg_log_los...
# 10        xgboost  xgboost_overnight_2026_03_20_neg_log_loss_2026...
# 11        xgboost  xgboost_overnight_2026_03_20_neg_log_loss_2026...
# 12        xgboost  xgboost_overnight_2026_03_20_neg_log_loss_2026...
# 13        xgboost  xgboost_overnight_2026_03_20_neg_log_loss_2026...
# 14        xgboost  xgboost_overnight_2026_03_20_neg_log_loss_2026...
#
#     outer_fold  n_train  n_val  train_positive_rate  val_positive_rate  \
# 0            0     8392   2069             0.112488           0.092798
# 1            1     8326   2135             0.108816           0.107728
# 2            2     8345   2116             0.101618           0.136106
# 3            3     8418   2043             0.104300           0.126285
# 4            4     8363   2098             0.115748           0.080076
# 5            0     8392   2069             0.112488           0.092798
# 6            1     8326   2135             0.108816           0.107728
# 7            2     8345   2116             0.101618           0.136106
# 8            3     8418   2043             0.104300           0.126285
# 9            4     8363   2098             0.115748           0.080076
# 10           0     8392   2069             0.112488           0.092798
# 11           1     8326   2135             0.108816           0.107728
# 12           2     8345   2116             0.101618           0.136106
# 13           3     8418   2043             0.104300           0.126285
# 14           4     8363   2098             0.115748           0.080076
#
#      roc_auc     aucpr  log_loss     brier       ece        f1    recall  \
# 0   0.590899  0.140598  0.307367  0.084030  0.031230  0.179795  0.546875
# 1   0.630261  0.174735  0.330943  0.094193  0.005815  0.230931  0.717391
# 2   0.646364  0.228346  0.389431  0.114711  0.039421  0.307974  0.583333
# 3   0.636188  0.193155  0.369851  0.108343  0.022073  0.258526  0.910853
# 4   0.674448  0.162463  0.271281  0.072607  0.034476  0.194677  0.761905
# 5   0.612559  0.151377  0.303311  0.083249  0.018012  0.200000  0.588542
# 6   0.665640  0.197432  0.324352  0.092590  0.008083  0.250435  0.626087
# 7   0.681607  0.240562  0.381979  0.114158  0.035168  0.329114  0.631944
# 8   0.617051  0.185415  0.369695  0.108054  0.009420  0.253051  0.763566
# 9   0.679173  0.174460  0.268113  0.071591  0.033015  0.209992  0.738095
# 10  0.630679  0.150602  0.301043  0.082986  0.012293  0.212649  0.604167
# 11  0.666849  0.199312  0.327080  0.093083  0.025016  0.234973  0.560870
# 12  0.667906  0.232421  0.385066  0.114704  0.035947  0.314005  0.611111
# 13  0.628594  0.186769  0.366713  0.107592  0.012102  0.253264  0.751938
# 14  0.694967  0.166079  0.269811  0.072007  0.034905  0.186015  0.815476
#
#     accuracy                                   best_params_json  \
# 0   0.536974  {"classifier__C": 0.0010672476836323724, "clas...
# 1   0.485246  {"classifier__C": 0.007890004262668575, "class...
# 2   0.643195  {"classifier__C": 0.0036084925884026665, "clas...
# 3   0.340186  {"classifier__C": 0.004809461967501573, "class...
# 4   0.495234  {"classifier__C": 0.024004075943521632, "class...
# 5   0.563074  {"classifier__bootstrap": true, "classifier__c...
# 6   0.596253  {"classifier__bootstrap": true, "classifier__c...
# 7   0.649338  {"classifier__bootstrap": true, "classifier__c...
# 8   0.430739  {"classifier__bootstrap": true, "classifier__c...
# 9   0.555291  {"classifier__bootstrap": true, "classifier__c...
# 10  0.584824  {"classifier__colsample_bytree": 0.71783644933...
# 11  0.606557  {"classifier__colsample_bytree": 0.54241885704...
# 12  0.636578  {"classifier__colsample_bytree": 0.71783644933...
# 13  0.440039  {"classifier__colsample_bytree": 0.71783644933...
# 14  0.428503  {"classifier__colsample_bytree": 0.52538426551...
#
#                                               run_dir
# 0   C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 1   C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 2   C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 3   C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 4   C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 5   C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 6   C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 7   C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 8   C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 9   C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 10  C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 11  C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 12  C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 13  C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 14  C:\Users\john\Desktop\spring-2026-radon-risk-m...

# %%
oof_dfs = []

for file in oof_files:
    df = pd.read_csv(file)
    df["run_dir"] = str(file.parent)
    oof_dfs.append(df)

all_oof_df = pd.concat(oof_dfs, ignore_index=True)

print(all_oof_df.columns.tolist())
all_oof_df
# Out:
# ['model_name', 'run_id', 'row_index', 'cv_fold', 'y_true', 'oof_prob', 'oof_pred_01', 'FSA', 'concentration', 'run_dir', 'oof_pred_at_threshold']
#       model_name                                             run_id  \
# 0         logreg  logreg_overnight_2026_03_20_neg_log_loss_20260...
# 1         logreg  logreg_overnight_2026_03_20_neg_log_loss_20260...
# 2         logreg  logreg_overnight_2026_03_20_neg_log_loss_20260...
# 3         logreg  logreg_overnight_2026_03_20_neg_log_loss_20260...
# 4         logreg  logreg_overnight_2026_03_20_neg_log_loss_20260...
# ...          ...                                                ...
# 31378    xgboost  xgboost_overnight_2026_03_20_neg_log_loss_2026...
# 31379    xgboost  xgboost_overnight_2026_03_20_neg_log_loss_2026...
# 31380    xgboost  xgboost_overnight_2026_03_20_neg_log_loss_2026...
# 31381    xgboost  xgboost_overnight_2026_03_20_neg_log_loss_2026...
# 31382    xgboost  xgboost_overnight_2026_03_20_neg_log_loss_2026...
#
#        row_index  cv_fold  y_true  oof_prob  oof_pred_01  FSA  concentration  \
# 0              0        0       0  0.110011          1.0  V8J            7.5
# 1              1        0       0  0.110011          1.0  V8J            7.5
# 2              2        0       0  0.110011          1.0  V8J            7.5
# 3              3        0       0  0.110011          1.0  V8J            7.5
# 4              4        0       0  0.110011          1.0  V8J            7.5
# ...          ...      ...     ...       ...          ...  ...            ...
# 31378      10456        2       0  0.066734          NaN  A1A            7.5
# 31379      10457        2       0  0.066734          NaN  A1A           18.0
# 31380      10458        2       0  0.066734          NaN  A1A           23.0
# 31381      10459        2       0  0.066734          NaN  A1A           40.0
# 31382      10460        2       0  0.066734          NaN  A1A           74.0
#
#                                                  run_dir  \
# 0      C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 1      C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 2      C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 3      C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 4      C:\Users\john\Desktop\spring-2026-radon-risk-m...
# ...                                                  ...
# 31378  C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 31379  C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 31380  C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 31381  C:\Users\john\Desktop\spring-2026-radon-risk-m...
# 31382  C:\Users\john\Desktop\spring-2026-radon-risk-m...
#
#        oof_pred_at_threshold
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 31378                    0.0
# 31379                    0.0
# 31380                    0.0
# 31381                    0.0
# 31382                    0.0
#
# [31383 rows x 11 columns]

# %%
all_oof_df.isna().sum().sort_values(ascending=False)
# Out:
# oof_pred_01              20922
# oof_pred_at_threshold    10461
# model_name                   0
# row_index                    0
# run_id                       0
# y_true                       0
# cv_fold                      0
# oof_prob                     0
# FSA                          0
# concentration                0
# run_dir                      0
# dtype: int64

# %%
core_columns = ["model_name", "y_true", "oof_prob"]
all_oof_df[core_columns].isna().sum()
# Out:
# model_name    0
# y_true        0
# oof_prob      0
# dtype: int64

# %%
comparison_df = all_summaries[[
    "model_name",
    "oof_roc_auc",
    "oof_aucpr",
    "oof_log_loss",
    "oof_brier",
    "oof_ece",
    "oof_f1",
    "oof_recall",
    "run_id",
]].copy()

comparison_df = comparison_df.sort_values(
    by=["oof_aucpr", "oof_log_loss"],
    ascending=[False, True]
)

comparison_df
# Out:
#       model_name  oof_roc_auc  oof_aucpr  oof_log_loss  oof_brier   oof_ece  \
# 1  random_forest     0.649478   0.183600      0.329423   0.093914  0.001278
# 2        xgboost     0.648099   0.181639      0.329914   0.094066  0.006074
# 0         logreg     0.628664   0.171108      0.333744   0.094767  0.005469
#
#      oof_f1  oof_recall                                             run_id
# 1  0.248204    0.669014  random_forest_overnight_2026_03_20_neg_log_los...
# 2  0.238163    0.661972  xgboost_overnight_2026_03_20_neg_log_loss_2026...
# 0  0.234863    0.705106  logreg_overnight_2026_03_20_neg_log_loss_20260...

# %%
fold_summary = (
    all_folds_df
    .groupby("model_name")
    .agg(
        mean_roc_auc=("roc_auc", "mean"),
        std_roc_auc=("roc_auc", "std"),
        mean_aucpr=("aucpr", "mean"),
        std_aucpr=("aucpr", "std"),
        mean_log_loss=("log_loss", "mean"),
        std_log_loss=("log_loss", "std"),
        mean_brier=("brier", "mean"),
        std_brier=("brier", "std"),
        mean_ece=("ece", "mean"),
        std_ece=("ece", "std"),
        mean_accuracy=("accuracy", "mean"),
        std_accuracy=("accuracy", "std"),
        mean_recall=("recall", "mean"),
        std_recall=("recall", "std"),
        mean_f1=("f1", "mean"),
        std_f1=("f1", "std"),
    )
    .reset_index()
)

fold_summary
# Out:
#       model_name  mean_roc_auc  std_roc_auc  mean_aucpr  std_aucpr  \
# 0         logreg      0.635632     0.030216    0.179859   0.033159
# 1  random_forest      0.651206     0.033819    0.189849   0.033038
# 2        xgboost      0.657799     0.028080    0.187037   0.031533
#
#    mean_log_loss  std_log_loss  mean_brier  std_brier  mean_ece   std_ece  \
# 0       0.333775      0.047460    0.094777   0.017239  0.026603  0.013232
# 1       0.329490      0.047038    0.093928   0.017490  0.020740  0.012793
# 2       0.329943      0.047037    0.094074   0.017459  0.024052  0.011633
#
#    mean_accuracy  std_accuracy  mean_recall  std_recall   mean_f1    std_f1
# 0       0.500167      0.109147     0.704071    0.146261  0.234380  0.051398
# 1       0.558939      0.080669     0.669647    0.076490  0.248518  0.050888
# 2       0.539300      0.097708     0.668712    0.109064  0.240181  0.048323

# %%
CLASSIFICATION_THRESHOLD = 0.1

metric_rows = []

for model_name, df_model in all_oof_df.groupby("model_name"):
    y_true = df_model["y_true"].values
    y_prob = df_model["oof_prob"].values
    y_pred = (y_prob >= CLASSIFICATION_THRESHOLD).astype(int)

    metric_rows.append({
        "model_name": model_name,
        "roc_auc": roc_auc_score(y_true, y_prob),
        "aucpr": average_precision_score(y_true, y_prob),
        "log_loss": log_loss(y_true, y_prob),
        "brier": brier_score_loss(y_true, y_prob),
        "ece": expected_calibration_error(y_true, y_prob, n_bins=10),
        "accuracy_at_threshold": accuracy_score(y_true, y_pred),
        "recall_at_threshold": recall_score(y_true, y_pred, zero_division=0),
        "f1_at_threshold": f1_score(y_true, y_pred, zero_division=0),
        "positive_rate": y_true.mean(),
        "predicted_positive_rate": y_pred.mean(),
    })

oof_metric_check_df = pd.DataFrame(metric_rows).sort_values(
    by=["aucpr", "log_loss"],
    ascending=[False, True]
)

oof_metric_check_df
# Out:
#       model_name   roc_auc     aucpr  log_loss     brier       ece  \
# 1  random_forest  0.649478  0.183600  0.329423  0.093914  0.001278
# 2        xgboost  0.648099  0.181639  0.329914  0.094066  0.006074
# 0         logreg  0.628664  0.171108  0.333744  0.094767  0.005469
#
#    accuracy_at_threshold  recall_at_threshold  f1_at_threshold  positive_rate  \
# 1               0.559889             0.669014         0.248204       0.108594
# 2               0.540101             0.661972         0.238163       0.108594
# 0               0.501099             0.705106         0.234863       0.108594
#
#    predicted_positive_rate
# 1                 0.476819
# 2                 0.495077
# 0                 0.543447

# %%
final_comparison_df = oof_metric_check_df.merge(
    fold_summary,
    on="model_name",
    how="left"
)

final_comparison_df[[
    "model_name",
    "aucpr",
    "roc_auc",
    "log_loss",
    "brier",
    "ece",
    "recall_at_threshold",
    "f1_at_threshold",
    "mean_aucpr",
    "std_aucpr",
    "mean_log_loss",
    "std_log_loss",
]]
# Out:
#       model_name     aucpr   roc_auc  log_loss     brier       ece  \
# 0  random_forest  0.183600  0.649478  0.329423  0.093914  0.001278
# 1        xgboost  0.181639  0.648099  0.329914  0.094066  0.006074
# 2         logreg  0.171108  0.628664  0.333744  0.094767  0.005469
#
#    recall_at_threshold  f1_at_threshold  mean_aucpr  std_aucpr  mean_log_loss  \
# 0             0.669014         0.248204    0.189849   0.033038       0.329490
# 1             0.661972         0.238163    0.187037   0.031533       0.329943
# 2             0.705106         0.234863    0.179859   0.033159       0.333775
#
#    std_log_loss
# 0      0.047038
# 1      0.047037
# 2      0.047460

# %%
plt.figure(figsize=(8, 4))

for model_name, df_model in all_oof_df.groupby("model_name"):
    precision, recall, _ = precision_recall_curve(
        df_model["y_true"],
        df_model["oof_prob"]
    )
    aucpr = average_precision_score(df_model["y_true"], df_model["oof_prob"])
    plt.plot(recall, precision, label=f"{model_name} (AUCPR={aucpr:.3f})")

baseline_prevalence = (
    all_oof_df.loc[all_oof_df["model_name"] == "logreg", "y_true"].mean()
)
plt.axhline(baseline_prevalence, linestyle="--", label=f"baseline={baseline_prevalence:.3f}")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve (OOF Predictions)")
plt.legend()


plt.savefig(os.path.join(FIGURES_DIR, "OOF_precision_recall_curve.png"), dpi=300, bbox_inches="tight")
plt.show()

# %%
def calibration_table(y_true, y_prob, n_bins=10):
    df = pd.DataFrame({"y_true": y_true, "y_prob": y_prob})
    df["bin"] = pd.qcut(df["y_prob"], q=n_bins, duplicates="drop")
    grouped = df.groupby("bin", observed=False).agg(
        mean_prob=("y_prob", "mean"),
        frac_positive=("y_true", "mean"),
        count=("y_true", "size")
    ).reset_index()
    return grouped

plt.figure(figsize=(8, 4))

for model_name, df_model in all_oof_df.groupby("model_name"):
    cal_df = calibration_table(df_model["y_true"], df_model["oof_prob"], n_bins=10)
    plt.plot(cal_df["mean_prob"], cal_df["frac_positive"], marker="o", label=model_name)

plt.plot([0, 1], [0, 1], linestyle="--")

plt.xlim(0.0, 0.35)
plt.ylim(0.0, 0.35)

plt.xlabel("Mean predicted probability")
plt.ylabel("Observed positive rate")
plt.title("Calibration Plot (OOF Predictions)")
plt.legend()

plt.savefig(os.path.join(FIGURES_DIR, "OOF_calibration_curve.png"), dpi=300, bbox_inches="tight")
plt.show()

# %%
thresholds = [0.05, 0.10, 0.15, 0.20, 0.30]

threshold_rows = []

for model_name, df_model in all_oof_df.groupby("model_name"):
    y_true = df_model["y_true"].values
    y_prob = df_model["oof_prob"].values

    for threshold in thresholds:
        y_pred = (y_prob >= threshold).astype(int)

        threshold_rows.append({
            "model_name": model_name,
            "threshold": threshold,
            "accuracy": accuracy_score(y_true, y_pred),
            "recall": recall_score(y_true, y_pred, zero_division=0),
            "f1": f1_score(y_true, y_pred, zero_division=0),
            "predicted_positive_rate": y_pred.mean(),
        })

threshold_df = pd.DataFrame(threshold_rows)
threshold_df
# Out:
#        model_name  threshold  accuracy    recall        f1  \
# 0          logreg       0.05  0.209445  0.952465  0.207399
# 1          logreg       0.10  0.501099  0.705106  0.234863
# 2          logreg       0.15  0.774209  0.323063  0.237080
# 3          logreg       0.20  0.870184  0.095951  0.138325
# 4          logreg       0.30  0.891215  0.000000  0.000000
# 5   random_forest       0.05  0.215371  0.954225  0.208944
# 6   random_forest       0.10  0.559889  0.669014  0.248204
# 7   random_forest       0.15  0.770481  0.364437  0.256426
# 8   random_forest       0.20  0.849441  0.161972  0.189398
# 9   random_forest       0.30  0.891406  0.000000  0.000000
# 10        xgboost       0.05  0.212599  0.970951  0.211242
# 11        xgboost       0.10  0.540101  0.661972  0.238163
# 12        xgboost       0.15  0.781187  0.382042  0.274945
# 13        xgboost       0.20  0.851926  0.132923  0.163155
# 14        xgboost       0.30  0.886340  0.029049  0.052590
#
#     predicted_positive_rate
# 0                  0.888825
# 1                  0.543447
# 2                  0.187363
# 3                  0.042061
# 4                  0.000191
# 5                  0.883281
# 6                  0.476819
# 7                  0.200076
# 8                  0.077144
# 9                  0.000000
# 10                 0.889685
# 11                 0.495077
# 12                 0.193194
# 13                 0.068349
# 14                 0.011376

# %%
threshold_plot_df = threshold_df.copy()

plt.figure(figsize=(7, 5))
for model_name, df_model in threshold_plot_df.groupby("model_name"):
    plt.plot(df_model["threshold"], df_model["f1"], marker="o", label=model_name)

plt.xlabel("Threshold")
plt.ylabel("F1")
plt.title("F1 vs Classification Threshold")
plt.legend()

plt.savefig(os.path.join(FIGURES_DIR, "OOF_classification_threshold_curve.png"), dpi=300, bbox_inches="tight")
plt.show()

# %%
threshold_df.pivot(index="threshold", columns="model_name", values="recall")
# Out:
# model_name    logreg  random_forest   xgboost
# threshold
# 0.05        0.952465       0.954225  0.970951
# 0.10        0.705106       0.669014  0.661972
# 0.15        0.323063       0.364437  0.382042
# 0.20        0.095951       0.161972  0.132923
# 0.30        0.000000       0.000000  0.029049

# %%
threshold_df.pivot(index="threshold", columns="model_name", values="f1")
# Out:
# model_name    logreg  random_forest   xgboost
# threshold
# 0.05        0.207399       0.208944  0.211242
# 0.10        0.234863       0.248204  0.238163
# 0.15        0.237080       0.256426  0.274945
# 0.20        0.138325       0.189398  0.163155
# 0.30        0.000000       0.000000  0.052590

# %%
all_folds_df[["model_name", "outer_fold", "best_params_json"]]
# Out:
#        model_name  outer_fold  \
# 0          logreg           0
# 1          logreg           1
# 2          logreg           2
# 3          logreg           3
# 4          logreg           4
# 5   random_forest           0
# 6   random_forest           1
# 7   random_forest           2
# 8   random_forest           3
# 9   random_forest           4
# 10        xgboost           0
# 11        xgboost           1
# 12        xgboost           2
# 13        xgboost           3
# 14        xgboost           4
#
#                                      best_params_json
# 0   {"classifier__C": 0.0010672476836323724, "clas...
# 1   {"classifier__C": 0.007890004262668575, "class...
# 2   {"classifier__C": 0.0036084925884026665, "clas...
# 3   {"classifier__C": 0.004809461967501573, "class...
# 4   {"classifier__C": 0.024004075943521632, "class...
# 5   {"classifier__bootstrap": true, "classifier__c...
# 6   {"classifier__bootstrap": true, "classifier__c...
# 7   {"classifier__bootstrap": true, "classifier__c...
# 8   {"classifier__bootstrap": true, "classifier__c...
# 9   {"classifier__bootstrap": true, "classifier__c...
# 10  {"classifier__colsample_bytree": 0.71783644933...
# 11  {"classifier__colsample_bytree": 0.54241885704...
# 12  {"classifier__colsample_bytree": 0.71783644933...
# 13  {"classifier__colsample_bytree": 0.71783644933...
# 14  {"classifier__colsample_bytree": 0.52538426551...

# %%
for _, row in all_folds_df.iterrows():
    print(row["model_name"], "| fold", row["outer_fold"])
    print(json.loads(row["best_params_json"]))
    print()
# Out:
# logreg | fold 0
# {'classifier__C': 0.0010672476836323724, 'classifier__class_weight': None, 'classifier__penalty': 'l2'}
#
# logreg | fold 1
# {'classifier__C': 0.007890004262668575, 'classifier__class_weight': None, 'classifier__penalty': 'l1'}
#
# logreg | fold 2
# {'classifier__C': 0.0036084925884026665, 'classifier__class_weight': None, 'classifier__penalty': 'l2'}
#
# logreg | fold 3
# {'classifier__C': 0.004809461967501573, 'classifier__class_weight': None, 'classifier__l1_ratio': 0.5, 'classifier__penalty': 'elasticnet'}
#
# logreg | fold 4
# {'classifier__C': 0.024004075943521632, 'classifier__class_weight': None, 'classifier__penalty': 'l1'}
#
# random_forest | fold 0
# {'classifier__bootstrap': True, 'classifier__class_weight': None, 'classifier__max_depth': 15, 'classifier__max_features': 'log2', 'classifier__min_samples_leaf': 7, 'classifier__min_samples_split': 5, 'classifier__n_estimators': 884}
#
# random_forest | fold 1
# {'classifier__bootstrap': True, 'classifier__class_weight': None, 'classifier__max_depth': 15, 'classifier__max_features': 'log2', 'classifier__min_samples_leaf': 7, 'classifier__min_samples_split': 5, 'classifier__n_estimators': 884}
#
# random_forest | fold 2
# {'classifier__bootstrap': True, 'classifier__class_weight': None, 'classifier__max_depth': 15, 'classifier__max_features': 'log2', 'classifier__min_samples_leaf': 7, 'classifier__min_samples_split': 5, 'classifier__n_estimators': 884}
#
# random_forest | fold 3
# {'classifier__bootstrap': True, 'classifier__class_weight': None, 'classifier__max_depth': None, 'classifier__max_features': 'sqrt', 'classifier__min_samples_leaf': 9, 'classifier__min_samples_split': 14, 'classifier__n_estimators': 944}
#
# random_forest | fold 4
# {'classifier__bootstrap': True, 'classifier__class_weight': None, 'classifier__max_depth': 15, 'classifier__max_features': 'log2', 'classifier__min_samples_leaf': 7, 'classifier__min_samples_split': 5, 'classifier__n_estimators': 884}
#
# xgboost | fold 0
# {'classifier__colsample_bytree': 0.7178364493389455, 'classifier__gamma': 1.460078633123637, 'classifier__learning_rate': 0.01153666052581368, 'classifier__max_depth': 4, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 235, 'classifier__reg_alpha': 0.00011802321563258201, 'classifier__reg_lambda': 0.0038050748350588197, 'classifier__scale_pos_weight': 1.0, 'classifier__subsample': 0.637662795307424}
#
# xgboost | fold 1
# {'classifier__colsample_bytree': 0.542418857042596, 'classifier__gamma': 1.973279157002351, 'classifier__learning_rate': 0.030685805769477312, 'classifier__max_depth': 3, 'classifier__min_child_weight': 6, 'classifier__n_estimators': 649, 'classifier__reg_alpha': 0.001525548321519627, 'classifier__reg_lambda': 34.55162931337358, 'classifier__scale_pos_weight': 1.0, 'classifier__subsample': 0.9013512741035766}
#
# xgboost | fold 2
# {'classifier__colsample_bytree': 0.7178364493389455, 'classifier__gamma': 1.460078633123637, 'classifier__learning_rate': 0.01153666052581368, 'classifier__max_depth': 4, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 235, 'classifier__reg_alpha': 0.00011802321563258201, 'classifier__reg_lambda': 0.0038050748350588197, 'classifier__scale_pos_weight': 1.0, 'classifier__subsample': 0.637662795307424}
#
# xgboost | fold 3
# {'classifier__colsample_bytree': 0.7178364493389455, 'classifier__gamma': 1.460078633123637, 'classifier__learning_rate': 0.01153666052581368, 'classifier__max_depth': 4, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 235, 'classifier__reg_alpha': 0.00011802321563258201, 'classifier__reg_lambda': 0.0038050748350588197, 'classifier__scale_pos_weight': 1.0, 'classifier__subsample': 0.637662795307424}
#
# xgboost | fold 4
# {'classifier__colsample_bytree': 0.5253842655196985, 'classifier__gamma': 1.7732342979013198, 'classifier__learning_rate': 0.010862511483797301, 'classifier__max_depth': 4, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 200, 'classifier__reg_alpha': 0.021280904885895843, 'classifier__reg_lambda': 0.516681811478353, 'classifier__scale_pos_weight': 1.0, 'classifier__subsample': 0.9355734008277453}

# %%
for model_name, df_model in all_oof_df.groupby("model_name"):
    plt.figure(figsize=(6, 4))
    plt.hist(df_model["oof_prob"], bins=30)
    plt.title(f"{model_name}: distribution of OOF predicted probabilities")
    plt.xlabel("Predicted probability")
    plt.ylabel("Count")
    plt.show()

# %%
for model_name, df_model in all_oof_df.groupby("model_name"):
    plt.figure(figsize=(6, 4))
    plt.hist(df_model.loc[df_model["y_true"] == 0, "oof_prob"], bins=30, alpha=0.6, label="y=0")
    plt.hist(df_model.loc[df_model["y_true"] == 1, "oof_prob"], bins=30, alpha=0.6, label="y=1")
    plt.title(f"{model_name}: OOF predicted probabilities by class")
    plt.xlabel("Predicted probability")
    plt.ylabel("Count")
    plt.legend()
    plt.show()
